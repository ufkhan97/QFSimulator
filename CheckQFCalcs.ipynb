# %%
import pandas as pd
import numpy as np
import requests
import datetime
import plotly.graph_objs as go
import plotly.express as px
import locale

# %%
# SKIP


def load_chain_data(chain_id):
    chain_url = 'https://indexer-grants-stack.gitcoin.co/data/' + chain_id + '/rounds.json'
    try:
        response = requests.get(chain_url)
        if response.status_code == 200:
            chain_data = response.json()
            rounds = []
            for round in chain_data:
                if round['metadata'] is not None:
                    round_data = {
                        'round_id': round['id'],
                        'name': round['metadata']['name'],
                        'amountUSD': round['amountUSD'],
                        'votes': round['votes'],
                        'description': round['metadata']['description'] if 'description' in round['metadata'] else '',
                        'matchingFundsAvailable': round['metadata']['matchingFunds']['matchingFundsAvailable'] if 'matchingFunds' in round['metadata'] else '',
                        'matchingCap': round['metadata']['matchingFunds']['matchingCap'] if 'matchingFunds' in round['metadata'] else '',
                        'roundStartTime': datetime.datetime.utcfromtimestamp(int(round['roundStartTime'])), # create a datetime object from the timestamp in UTC time
                        'roundEndTime': datetime.datetime.utcfromtimestamp(int(round['roundEndTime']))
                    }
                    rounds.append(round_data)
            df = pd.DataFrame(rounds)
            #start_time = datetime.datetime(2023, 4, 26, 15, 0, 0)
            #end_time = datetime.datetime(2023, 5, 9, 23, 59, 0)
            df = df[(df['votes'] > 0)] #& (df['roundStartTime'] <= start_time) & (df['roundEndTime'] == end_time)]
            return df 
    except: 
        return pd.DataFrame()
    
def load_round_projects_data(round_id):
    # prepare the URLs
    projects_url = 'https://indexer-grants-stack.gitcoin.co/data/1/rounds/' + round_id + '/projects.json'
    
    try:
        # download the Projects JSON data from the URL
        response = requests.get(projects_url)
        if response.status_code == 200:
            projects_data = response.json()

        # Extract the relevant data from each project
        projects = []
        for project in projects_data:
            project_data = {
                'id': project['id'],
                'title': project['metadata']['application']['project']['title'],
                'description': project['metadata']['application']['project']['description'],
                'status': project['status'],
                'amountUSD': project['amountUSD'],
                'votes': project['votes'],
                'uniqueContributors': project['uniqueContributors']
            }
            projects.append(project_data)
        # Create a DataFrame from the extracted data
        dfp = pd.DataFrame(projects)
        # Reorder the columns to match the desired order and rename column id to project_id
        dfp = dfp[['id', 'title', 'description', 'status', 'amountUSD', 'votes', 'uniqueContributors']]
        dfp = dfp.rename(columns={'id': 'project_id'})
        # Filter to only approved projects
        #dfp = dfp[dfp['status'] == 'APPROVED']
        return dfp
    except:
        return pd.DataFrame()
    
def load_round_votes_data(round_id):
    votes_url = 'https://indexer-grants-stack.gitcoin.co/data/1/rounds/' + round_id + '/votes.json'
    try:
        # download the Votes JSON data from the URL
        response = requests.get(votes_url)
        if response.status_code == 200:
            votes_data = response.json()
        df = pd.DataFrame(votes_data)
        return df
    except:
        return pd.DataFrame()
    

def load_all_votes_data(chain_data):
    dfv_all = pd.DataFrame()
    for round_id in chain_data['round_id']:
        if round_id == '0x0000000000000000000000000000000000000000':
            print("*******DUDE Skipping round 0")
            continue
        #print("Loading Round with ID: " + round_id)
        dfv = load_round_votes_data(round_id)
        dfp = load_round_projects_data(round_id)
        dfv = pd.merge(dfv, dfp[['project_id', 'title', 'status']], how='left', left_on='projectId', right_on='project_id')
        # CHECK IF chain_data has columns roun_type and matching_amount
        if 'round_type' not in chain_data.columns:
            chain_data['round_type'] = ''
        if 'matching_amount' not in chain_data.columns:
            chain_data['matching_amount'] = 0
        if 'round_name' not in chain_data.columns:
            #rename name column to round_name
            chain_data = chain_data.rename(columns={'name': 'round_name'})
        dfv = pd.merge(dfv, chain_data[['round_id', 'round_name', 'round_type', 'matching_amount']], how='left', left_on='roundId', right_on='round_id')
        dfv_all = pd.concat([dfv_all, dfv])
    return dfv_all

def load_passport_data():
    url = 'https://indexer-grants-stack.gitcoin.co/data/passport_scores.json'
    try:
        response = requests.get(url)
        response.raise_for_status()
        passports_data = response.json()
        if not passports_data:
            raise ValueError('Passport data is empty')
        else:
            print("Passport data loaded successfully!")
        passports = []
        for passport in passports_data:
            data = {
                'address': passport.get('address', ''),
                'score': passport.get('score', ''),
                'status': passport.get('status', ''),
                'last_score_timestamp': passport.get('last_score_timestamp', ''),
                'evidence_type': passport['evidence'].get('type', '') if passport.get('evidence') else '',
                'evidence_success': passport['evidence'].get('success', '') if passport.get('evidence') else '',
                'evidence_rawScore': passport['evidence'].get('rawScore', '') if passport.get('evidence') else '',
                'evidence_threshold': passport['evidence'].get('threshold', '') if passport.get('evidence') else '',
                'error': passport.get('error', ''),
            }
            passports.append(data)
        df = pd.DataFrame(passports)
        return df
    except Exception as e:
        print("Error:", e)
        return pd.DataFrame()

# %%
# SKIP 
chain_id = '1'
df = load_chain_data(chain_id)
df_all = load_all_votes_data(df)
display(df_all)
# save df_all to a csv
df_all.to_csv('beta_votes_all.csv', index=False)
df = load_passport_data()
# Save to CSV
df.to_csv('passport_data.csv', index=False)
# Out:
# Loading Round with ID: 0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# Loading Round with ID: 0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094
# Loading Round with ID: 0x274554EB289004e15A7679123901B7F070dDa0fa
# Loading Round with ID: 0xAA40E2E5c8df03d792A52B5458959C320F86ca18
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       2 chain_id = '1'
#       3 df = load_chain_data(chain_id)
# ----> 4 df_all = load_all_votes_data(df)
#       5 display(df_all)
#       6 # save df_all to a csv
#
# Cell In[2], line 89, in load_all_votes_data(chain_data)
#      87 dfv = load_round_votes_data(round_id)
#      88 dfp = load_round_projects_data(round_id)
# ---> 89 dfv = pd.merge(dfv, dfp[['project_id', 'title', 'status']], how='left', left_on='projectId', right_on='project_id')
#      90 # CHECK IF chain_data has columns roun_type and matching_amount
#      91 if 'round_type' not in chain_data.columns:
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/streamy/lib/python3.11/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['project_id', 'title', 'status'], dtype='object')] are in the [columns]"

# %%
# read dfs from csvs
## START HERE
df_all = pd.read_csv('beta_votes_all.csv')
df_pp = pd.read_csv('passport_data.csv')

# %%
display(load_chain_data(chain_id))
# Out:
#                                       round_id  \
# 5   0x350E2257548dF38C6b2009245332d73f5919834e
# 6   0xD95A1969c41112cEE9A2c931E849bCef36a16F4C
# 7   0x1b165fE4DA6bC58AB8370DDC763d367D29F50Ef0
# 8   0xe575282b376E3c9886779A841A2510F1Dd8C2CE4
# 12  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 13  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094
# 15  0x274554EB289004e15A7679123901B7F070dDa0fa
# 16  0xAA40E2E5c8df03d792A52B5458959C320F86ca18
# 17  0x421510312C40486965767be5Ea603Aa8a5707983
# 18  0x8aA06b3b8cAc2970857F4E0fD78F21dc01AAdE94
# 19  0x905eFBaBe2d52cD648FAdfafCeC8D6C8c60F7423
# 20  0x9E669c0A6e075F14ba9d9D98C3580aD67E20ec38
# 21  0x9C3B81967EafBA0a451E324417DD4F3F353b997b
# 22  0xF1C021DF6Dc6b2dC2E5A837CDFDDC2f42503233B
# 23  0x6e8dC2e623204D61b0E59E668702654aE336c9f7
# 25  0x64E5b2228eF31437909900B38fC42Dd5E4B83147
# 26  0x859FaeAa266BA13bd1E72eB6dd7A223902d1adFE
# 27  0x32c49d2dA5f6866a057e4aA2058c62A2974a5623
# 28  0x64aa545C9C63944f8e765d9a65eda3cbbDc6e620
#
#                                    name  amountUSD   votes description  \
# 5                   testing testing 123       1.13       2
# 6       Web3 Open Source Software Round  502550.02  161129
# 7               Climate Solutions Round   76855.60   14515
# 8         Ethereum Infrastructure Round   94880.05   20967
# 12      Web3 Open Source Software Round  330870.67   81811
# 13              Ethereum Infrastructure   41960.92    4307
# 15                        ZK Tech Round   31238.92    8605
# 16         Web3 Community and Education   62567.68    2896
# 17                    Climate Solutions   40646.31    1970
# 18                           Metacrisis   17754.87     600
# 19                   The Phantom Menace    1551.86     207
# 20                    Token Engineering    6134.03     257
# 21                          Web3 Social   25477.88    2546
# 22                      Mantle Grants 1    9418.50    1368
# 23        DeSci (Decentralized Science)   18675.17    1042
# 25                        ENS Ecosystem    8799.30     696
# 26  Global Chinese Community beta round    1967.77     203
# 27                      Crypto Advocacy    7877.77     613
# 28                     ReFi Local Nodes     980.70     115
#
#    matchingFundsAvailable matchingCap      roundStartTime        roundEndTime
# 5                   10000       False 2023-01-05 22:51:00 2023-01-08 00:00:00
# 6               333333.57        True 2023-01-17 12:00:00 2023-01-31 23:59:00
# 7               333333.56        True 2023-01-17 12:00:00 2023-01-31 23:59:00
# 8               333333.56        True 2023-01-17 12:00:00 2023-01-31 23:59:00
# 12                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 13                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 15                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 16                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 17                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 18                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 19                                    2023-04-25 00:00:00 2023-05-09 23:59:00
# 20                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 21                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 22                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 23                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 25                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 26                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 27                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 28                                    2023-04-26 15:00:00 2023-05-09 23:59:00

# %%
### ADJUST PARAMETERS HERE
min_passport_score = 15.0
min_amountUSD = .90
power = 2 # change to 2
matching_cap_ratio = 0.10
matching_pool = 350000


def get_matching(votes_data):
    votes_data = get_voting_weights(votes_data)
    votes_data = votes_data[votes_data['voting_success'] == True]
    project_data = votes_data.groupby(['title']).agg({'amountUSD': 'sum', 'sqrt_amountUSD':'sum', 'id': 'sum', 'voter': 'nunique'}).reset_index().sort_values('amountUSD', ascending=False)
    project_data = project_data.rename(columns={'sqrt_amountUSD': 'sum_sqrt_amountUSD'})
    project_data['squared_sum_sqrts'] = project_data['sum_sqrt_amountUSD'] ** power
    project_data['squared_sum_sqrts_minus_donations'] = project_data['squared_sum_sqrts'] - project_data['amountUSD'] #minus green squares
    project_data['matching_ratio'] = project_data['squared_sum_sqrts_minus_donations'] / project_data['squared_sum_sqrts_minus_donations'].sum()
    project_data['matching_amount'] = project_data['matching_ratio'] * matching_pool
    if (project_data['matching_ratio'] > matching_cap_ratio).any():
        project_data = check_matching_cap(project_data)
    round_saturation = (project_data['squared_sum_sqrts_minus_donations'].sum() / matching_pool) * 100
    print("Round Saturation: " + '{:,.2f}'.format(round_saturation) + "%") 
    return project_data

def get_voting_weights(votes_data):
    votes_data_with_weights = votes_data#.groupby(['voter', 'title']).agg({'amountUSD': 'sum', 'id': 'nunique'}).reset_index().sort_values('amountUSD', ascending=False)
    # flag where min_amount_usd threshold not met 
    votes_data_with_weights['amountUSD_above_min'] = np.where(votes_data_with_weights['amountUSD'] > min_amountUSD, True, False)
    votes_data_with_weights['passport_score'] = votes_data_with_weights['voter'].str.lower().map(df_pp.set_index('address')['evidence_rawScore'])
    votes_data_with_weights['passport_success'] = np.where(votes_data_with_weights['passport_score'] >= min_passport_score, True, False)
    votes_data_with_weights['voting_success'] = (votes_data_with_weights['amountUSD_above_min'] & votes_data_with_weights['passport_success'])
    votes_data_with_weights['sqrt_amountUSD'] = (votes_data_with_weights['amountUSD']) ** (1/power)
    return votes_data_with_weights

def check_matching_cap(project_data):
    matching_cap_amount = matching_cap_ratio * matching_pool
    while True:
        # Calculate over cap amounts and total uncapped fund
        over_cap = np.maximum(0, project_data['matching_amount'] - matching_cap_amount)
        total_fund_for_not_capped = project_data['matching_amount'][project_data['matching_amount'] < matching_cap_amount].sum()

        # Reduce matching amounts that are over cap
        project_data.loc[project_data['matching_amount'] > matching_cap_amount, 'matching_amount'] = matching_cap_amount
               # Calculate remainder percent and update matching amounts
        if total_fund_for_not_capped > 0:
            remainder_percent = over_cap.sum() / total_fund_for_not_capped
            project_data.loc[project_data['matching_amount'] < matching_cap_amount, 'matching_amount'] *= (1 + remainder_percent)
        else:
            break  # Exit loop when there's no fund left for not capped projects
        
        # Ensure that updates didn't push any projects over the cap
        over_cap_after_update = np.maximum(0, project_data['matching_amount'] - matching_cap_amount)
        if not over_cap_after_update.sum() > 0:
            break  # Exit loop when there's no amount over cap
    project_data['matching_ratio'] = project_data['matching_amount'] / matching_pool
    return project_data

# %%
# filter df_all to only include round_id that is 0x274554EB289004e15A7679123901B7F070dDa0fa
df_zk = df_all[df_all['round_id'] == '0x421510312C40486965767be5Ea603Aa8a5707983']
#df_test = get_voting_weights(df_zk)
# save to csv
#df_test.to_csv('beta_votes_oss_new.csv', index=False)
df_test = get_matching(df_zk)
df_test = df_test.sort_values('matching_ratio', ascending=False)
# display without scientific notation 
pd.options.display.float_format = '{:.2f}'.format
# print dataframe matching_amount and matching_ratio sums
print("matching_amount sum: " + '{:,.2f}'.format(df_test['matching_amount'].sum()))
print("matching_ratio sum: " + '{:,.2f}'.format(df_test['matching_ratio'].sum()))
#display(df_test)
# filter to title, matching_amount, matching_ratio
df_test = df_test[['title', 'matching_amount', 'matching_ratio']]
# display all rows
pd.set_option('display.max_rows', None)
# display dataframe
display(df_test.reset_index(drop=True))
# Out:
# Round Saturation: 116.51%
# matching_amount sum: 350,000.00
# matching_ratio sum: 1.00
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/883549841.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['amountUSD_above_min'] = np.where(votes_data_with_weights['amountUSD'] > min_amountUSD, True, False)
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/883549841.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['passport_score'] = votes_data_with_weights['voter'].str.lower().map(df_pp.set_index('address')['evidence_rawScore'])
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/883549841.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['passport_success'] = np.where(votes_data_with_weights['passport_score'] >= min_passport_score, True, False)
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/883549841.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['voting_success'] = (votes_data_with_weights['amountUSD_above_min'] & votes_data_with_weights['passport_success'])
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/883549841.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['sqrt_amountUSD'] = (votes_data_with_weights['amountUSD']) ** (1/power)
#                                                  title  matching_amount  \
# 0                                             Atlantis         35000.00
# 1                        WarmOFF - CO₂ removal project         35000.00
# 2                               $Earth - Solarpunk Dao         32091.31
# 3                                            Block2030         25267.45
# 4    Treegens - The Most Transparent & Rewarding Tr...         24039.83
# 5                                         Mini Meadows         22453.27
# 6    diosdao.xyz by Mycelia : Indigenous Public Goo...         22069.17
# 7                                     Treejer Protocol         20397.04
# 8                                             WaterDAO         10146.52
# 9                                            Web3beach          9934.32
# 10   GainForest: A Planetary Computer for ReFi powe...          9102.63
# 11                                               Silvi          8394.00
# 12   Barichara Regeneration Fund – Prototyping a Bi...          8167.86
# 13           Impact Verification Infrastructure Bundle          5477.72
# 14                                            Urbanika          5413.22
# 15                                              BETTER          5216.86
# 16                                The Solar Foundation          4703.51
# 17                             GeoNFT & Fractionalizer          4040.79
# 18                                       AgroforestDAO          4001.91
# 19                 KOKO DAO saving forests in Colombia          3860.73
# 20                           The Impact App + Eco Labs          3465.22
# 21             Shamba DMRV and Ecological Data Oracle.          3247.65
# 22                                              dMeter          2958.76
# 23   Kokonut Network; Building an Eco-Friendly Perp...          2906.56
# 24   Endangered Tokens: Endangered Trees as ReFi Bi...          2698.62
# 25   Solarpunk nomads: tracing nomadic routes with ...          2692.07
# 26                                           Crowdmuse          2425.25
# 27   AYOWECCA UGANDA:       Training rural farmers ...          2372.16
# 28   Simbiotica | The source for impact insights on...          2014.63
# 29   Digital Gaia: A Science-Based Co-Pilot to Defe...          1741.69
# 30                                          Sympoiesis          1606.81
# 31                   The Ecological Benefits Framework          1460.76
# 32                                       Bloom Network          1373.13
# 33            Climate & Nature Hyperstructure | .basin          1353.21
# 34                                  Rebuilding Turkiye          1252.06
# 35                                              R3WILD          1151.60
# 36                                       Healing Coral          1123.42
# 37                                             Ekonavi          1027.89
# 38                       Kula कुल Regenerative Commons           982.64
# 39                                      de_plan ostrom           952.47
# 40   Kawagumba village: a Kenyan community farm pro...           922.86
# 41                                         Oceans DAO            904.80
# 42                                 Non-Fungible Plants           725.84
# 43                                  Plants And Pillars           548.55
# 44                        Climate Attestation Protocol           535.40
# 45                                        Litter Token           514.80
# 46                                             Rebioca           500.54
# 47                                          Watercycle           495.05
# 48                                     Younergy Crypto           493.74
# 49                            Coffee Impact Collective           492.74
# 50                                          Myseelia 🍄           462.78
# 51                                Knysna Alien Busters           456.39
# 52                                     Astral Protocol           445.13
# 53                             Green Digital Guardians           442.95
# 54   The Wildlife Movement Institute: An Open-Sourc...           442.37
# 55                                            TaterDAO           430.36
# 56                                             ECORISE           346.06
# 57   Elephant in the Room Strategic Climate Solutions            343.64
# 58                                        Fightersgang           325.20
# 59                                         KNS Domains           320.84
# 60                                        Emerging.Eco           287.79
# 61                           Cosmos for Humanity | C4H           284.20
# 62                       Ranna: Filmmakers for Climate           272.51
# 63                                           Cambiatus           269.13
# 64                                         oxygenchain           268.79
# 65                                           Bloomeria           247.23
# 66       Nawonmesh - Regenerating Buxar (Bihar, India)           246.92
# 67   MesoReefDAO - Regenerating Reef Conservation w...           240.14
# 96             0.00
# 97             0.00
# 98             0.00
# 99             0.00
# 100            0.00
# 101            0.00
# 102            0.00
# 103            0.00

# %%
# filter df_all to only include round_id that is 0x274554EB289004e15A7679123901B7F070dDa0fa
df_zk = df_all[df_all['round_id'] == '0x421510312C40486965767be5Ea603Aa8a5707983']
#df_test = get_voting_weights(df_zk)
# save to csv
#df_test.to_csv('beta_votes_oss_new.csv', index=False)
df_test = get_matching(df_zk)
df_test = df_test.sort_values('matching_ratio', ascending=False)
# display without scientific notation 
pd.options.display.float_format = '{:.2f}'.format
# print dataframe matching_amount and matching_ratio sums
print("matching_amount sum: " + '{:,.2f}'.format(df_test['matching_amount'].sum()))
print("matching_ratio sum: " + '{:,.2f}'.format(df_test['matching_ratio'].sum()))
#display(df_test)
# filter to title, matching_amount, matching_ratio
df_test = df_test[['title', 'matching_amount', 'matching_ratio']]
# display all rows
pd.set_option('display.max_rows', None)
# display dataframe
display(df_test.reset_index(drop=True))
# Out:
# Round Saturation: 123.01%
# matching_amount sum: 350,000.00
# matching_ratio sum: 1.00
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/2497222026.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['amountUSD_above_min'] = np.where(votes_data_with_weights['amountUSD'] > min_amountUSD, True, False)
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/2497222026.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['passport_score'] = votes_data_with_weights['voter'].str.lower().map(df_pp.set_index('address')['evidence_rawScore'])
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/2497222026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['passport_success'] = np.where(votes_data_with_weights['passport_score'] >= min_passport_score, True, False)
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/2497222026.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['voting_success'] = (votes_data_with_weights['amountUSD_above_min'] & votes_data_with_weights['passport_success'])
# /var/folders/vc/4gnlrkhx1bqgc_p_rhn78pxh0000gn/T/ipykernel_871/2497222026.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votes_data_with_weights['sqrt_amountUSD'] = (votes_data_with_weights['amountUSD']) ** (1/power)
#                                                  title  matching_amount  \
# 0                        WarmOFF - CO₂ removal project         35000.00
# 1                                             Atlantis         35000.00
# 2                               $Earth - Solarpunk Dao         31492.39
# 3    Treegens - The Most Transparent & Rewarding Tr...         26071.08
# 4                                            Block2030         24074.07
# 5    diosdao.xyz by Mycelia : Indigenous Public Goo...         21577.05
# 6                                         Mini Meadows         21124.42
# 7                                     Treejer Protocol         19189.88
# 8                                            Web3beach         10257.95
# 9                                             WaterDAO          9546.02
# 10   GainForest: A Planetary Computer for ReFi powe...          9091.36
# 11                                               Silvi          8059.44
# 12   Barichara Regeneration Fund – Prototyping a Bi...          7866.71
# 13                                            Urbanika          5910.54
# 14                                              BETTER          5187.52
# 15           Impact Verification Infrastructure Bundle          5153.53
# 16                                The Solar Foundation          4937.69
# 17                 KOKO DAO saving forests in Colombia          4335.81
# 18                                       AgroforestDAO          4229.29
# 19                             GeoNFT & Fractionalizer          3918.41
# 20                           The Impact App + Eco Labs          3591.18
# 21             Shamba DMRV and Ecological Data Oracle.          3584.24
# 22   Kokonut Network; Building an Eco-Friendly Perp...          3230.94
# 23   Solarpunk nomads: tracing nomadic routes with ...          3218.76
# 24   Endangered Tokens: Endangered Trees as ReFi Bi...          2933.97
# 25                                              dMeter          2885.68
# 26   AYOWECCA UGANDA:       Training rural farmers ...          2596.45
# 27                                           Crowdmuse          2375.04
# 28   Simbiotica | The source for impact insights on...          2058.68
# 29   Digital Gaia: A Science-Based Co-Pilot to Defe...          1638.61
# 30                                       Bloom Network          1571.02
# 31                                          Sympoiesis          1511.71
# 32            Climate & Nature Hyperstructure | .basin          1407.07
# 33                                  Rebuilding Turkiye          1378.59
# 34                   The Ecological Benefits Framework          1374.31
# 35                                      de_plan ostrom          1261.33
# 36                                              R3WILD          1210.22
# 37   Kawagumba village: a Kenyan community farm pro...          1157.33
# 38                       Kula कुल Regenerative Commons          1100.33
# 39                                       Healing Coral          1056.93
# 40                                             Ekonavi          1026.79
# 41                                         Oceans DAO            963.59
# 42                                 Non-Fungible Plants           682.89
# 43                                        Litter Token           568.01
# 44                             Green Digital Guardians           538.01
# 45                                  Plants And Pillars           516.08
# 46                                          Myseelia 🍄           515.34
# 47                        Climate Attestation Protocol           503.72
# 48                                        Fightersgang           489.66
# 49                                             Rebioca           470.91
# 50                                Knysna Alien Busters           470.65
# 51                                          Watercycle           465.76
# 52                                     Younergy Crypto           464.52
# 53                            Coffee Impact Collective           463.58
# 54                                     Astral Protocol           458.67
# 55   The Wildlife Movement Institute: An Open-Sourc...           455.71
# 56                                            TaterDAO           444.19
# 57                           Cosmos for Humanity | C4H           399.21
# 58                                         KNS Domains           335.62
# 59                                             ECORISE           325.58
# 60   Elephant in the Room Strategic Climate Solutions            323.30
# 61                                        Emerging.Eco           306.32
# 62                       Ranna: Filmmakers for Climate           287.72
# 63                                           Cambiatus           283.27
# 64                                         oxygenchain           252.88
# 65                                 Sungura Mjanja Refi           245.38
# 66                                           Bloomeria           232.60
# 67       Nawonmesh - Regenerating Buxar (Bihar, India)           232.30
# 68   MesoReefDAO - Regenerating Reef Conservation w...           225.93
# 69                       KUMO - Money Backed By Nature           222.79
# 70      Hazel - Mobile Game That Fights Climate Change           219.13
# 71                                          Climecheck           217.67
# 72                                              regrò            203.47
# 73                                    D-MRV for Africa           177.89
# 74                           Tree Tales: Play to Plant           172.79
# 75         Realtime Climate Data Extension (RealClime)           171.14
# 76   DeFood: Decentralized Food Security Network (D...           159.04
# 77                                   Carbon Anti-Theft           154.67
# 78                                     Bye Bye Plastic           152.24
# 79                                           Agrii DAO           144.96
# 80                 Wild Friends: Play to save wildlife           144.30
# 81          7Energy - Energy Communities without Banks           144.00
# 82                                            Biolumen           141.06
# 83                        DexGrid Community Microgrids           136.75
# 84                                                Vean           123.57
# 85                                       Proof of Zero           120.46
# 86                                               Avano           108.39
# 87   The Angry Teenagers - democratising investment...           104.77
# 88    Proof of Renewable Energy Production (PREPchain)            90.59
# 89                                          ECOHUELLAS            87.38
# 90                                Fundación Tucultura             83.96
# 91   CCC: photojournalism expeditions on the field ...            79.85
# 92                                 SISU Living Portals            75.60
# 93                                        Rescua.Earth            74.83
# 94                                         Pulso Verde            57.58
# 95                                             DrinkUP            56.44
# 96                          Heating with Compute Power            55.14
# 97                                             libpwrm            38.68
# 98                        DLTEO (soon to be Orbuculum)            35.99
# 99                                            Empathia            33.48
# 100                             Regeneratie Coöperatie            32.74
# 101  Mirage Arts Community - Putting into action or...            26.58
# 102                                          Poops NFT            26.02
# 103                                             Palta3            12.35
#
#      matching_ratio
# 0              0.10
# 1              0.10
# 2              0.09
# 3              0.07
# 4              0.07
# 5              0.06
# 6              0.06
# 7              0.05
# 8              0.03
# 9              0.03
# 10             0.03
# 11             0.02
# 12             0.02
# 13             0.02
# 14             0.01
# 15             0.01
# 16             0.01
# 17             0.01
# 18             0.01
# 19             0.01
# 20             0.01
# 21             0.01
# 22             0.01
# 23             0.01
# 24             0.01
# 25             0.01
# 26             0.01
# 27             0.01
# 28             0.01
# 29             0.00
# 30             0.00
# 31             0.00
# 32             0.00
# 33             0.00
# 34             0.00
# 35             0.00
# 36             0.00
# 37             0.00
# 38             0.00
# 39             0.00
# 40             0.00
# 41             0.00
# 42             0.00
# 43             0.00
# 44             0.00
# 45             0.00
# 46             0.00
# 47             0.00
# 48             0.00
# 49             0.00
# 50             0.00
# 51             0.00
# 52             0.00
# 53             0.00
# 54             0.00
# 55             0.00
# 56             0.00
# 57             0.00
# 58             0.00
# 59             0.00
# 60             0.00
# 61             0.00
# 62             0.00
# 63             0.00
# 64             0.00
# 65             0.00
# 66             0.00
# 67             0.00
# 68             0.00
# 69             0.00
# 70             0.00
# 71             0.00
# 72             0.00
# 73             0.00
# 74             0.00
# 75             0.00
# 76             0.00
# 77             0.00
# 78             0.00
# 79             0.00
# 80             0.00
# 81             0.00
# 82             0.00
# 83             0.00
# 84             0.00
# 85             0.00
# 86             0.00
# 87             0.00
# 88             0.00
# 89             0.00
# 90             0.00
# 91             0.00
# 92             0.00
# 93             0.00
# 94             0.00
# 95             0.00
# 96             0.00
# 97             0.00
# 98             0.00
# 99             0.00
# 100            0.00
# 101            0.00
# 102            0.00
# 103            0.00

# %%
# filter df_all to only include round_id that is 0x274554EB289004e15A7679123901B7F070dDa0fa
df_zk = df_all[df_all['round_id'] == '0x274554EB289004e15A7679123901B7F070dDa0fa']
matching_pool = 150000
#df_test = get_voting_weights(df_zk)
df_test = get_matching(df_zk, matching_pool)
df_test = df_test.sort_values('matching_ratio', ascending=False)
# display without scientific notation 
pd.options.display.float_format = '{:.2f}'.format
display(df_test)
# Out:
# Round Saturation: 9,099.72%
#                                                 title  amountUSD  \
# 10                                              zkBob    4163.12
# 2                              Halo2 Backend for Noir    3250.49
# 9                                            ZeroPool    2866.01
# 4                                  Proof of Innocence    3946.03
# 0                                           4EVERLAND    1969.24
# 5                                      Sprintcheckout    1839.15
# 11                                             zkREPL    1822.92
# 1                                                EZKL    2377.81
# 3   PLUME: Pseudonymously Linked Unique Message En...    1770.33
# 6                            Switch Electric: Maxwell    1223.30
# 8                              Zero Knowledge Podcast    1367.90
# 7                                   Trustless zkMafia    1171.91
#
#     sum_sqrt_amountUSD    id  voter  squared_sum_sqrts  \
# 10             1709.63  1016    993         2922822.00
# 2              1413.00   865    847         1996579.06
# 9              1281.23   827    807         1641558.28
# 4              1225.45   774    756         1501726.42
# 0              1028.87   730    711         1058569.29
# 5               990.63   705    688          981356.55
# 11              975.58   692    675          951755.52
# 1               919.32   642    624          845141.38
# 3               887.79   637    624          788173.31
# 6               667.68   536    528          445794.41
# 8               580.90   350    340          337447.98
# 7               454.35   273    270          206429.87
#
#     squared_sum_sqrts_minus_donations  matching_ratio  matching_amount
# 10                         2918658.88            0.21         32074.15
# 2                          1993328.56            0.15         21905.37
# 9                          1638692.27            0.12         18008.15
# 4                          1497780.39            0.11         16459.62
# 0                          1056600.05            0.08         11611.34
# 5                           979517.41            0.07         10764.25
# 11                          949932.60            0.07         10439.14
# 1                           842763.57            0.06          9261.42
# 3                           786402.98            0.06          8642.05
# 6                           444571.11            0.03          4885.55
# 8                           336080.08            0.02          3693.30
# 7                           205257.97            0.02          2255.65

# %%
display(df_all.head(5))
# Out:
#                                                   id  \
# 0  0xd9154a180dbccb2a854223eb1cdef145e96faa174616...
# 1  0x28a2a4e9aa3c3a0853572c12b4f7fd948f5e4a9d2384...
# 2  0x4350cdd06449fcac96f5ceea26929efdf9d3f420fca6...
# 3  0x0f8ed9cb2aa39a8b766637c0bf5e1860bd4557292ff9...
# 4  0x7674f1341ac2bc442770d6a5fe3ff59bb89f2b44ed48...
#
#                                          transaction  blockNumber  \
# 0  0x0328340819a513652d554fd0f558ac2eb360b57e126e...     17123199
# 1  0xba2f9df050c6cd43a2676eb64bc81df2e193ece3ceb7...     17123217
# 2  0x986bdbdc0430eed93518a84dce9d98aef7385c0a9237...     17123229
# 3  0x986bdbdc0430eed93518a84dce9d98aef7385c0a9237...     17123229
# 4  0x986bdbdc0430eed93518a84dce9d98aef7385c0a9237...     17123229
#
#                                            projectId  applicationId  \
# 0  0x60c037f9dfa5daee0f07bc26fb73393ef924e36c73c4...             18
# 1  0xf05829c76e3da92a8942378240ab4dc70c8c509f558e...             13
# 2  0xb6a332decc38c703130a537ce7fcfe5a24bd85e52e07...              6
# 3  0xbe519f8c8f7ff2acb359dd757c5d2bf25b05d9fd29b8...              9
# 4  0x60c037f9dfa5daee0f07bc26fb73393ef924e36c73c4...             18
#
#                                       roundId  \
# 0  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 1  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 2  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 3  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 4  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
#
#                                         voter  \
# 0  0xa37d20cd446898508Ab961c6Be8d3fe1c15413fA
# 1  0xa37d20cd446898508Ab961c6Be8d3fe1c15413fA
# 2  0x0Cac11a7D29aB8C87D8fedB9Cc736146f4fe8E84
# 3  0x0Cac11a7D29aB8C87D8fedB9Cc736146f4fe8E84
# 4  0x0Cac11a7D29aB8C87D8fedB9Cc736146f4fe8E84
#
#                                  grantAddress  \
# 0  0x18aa467E40E1deFB1956708830A343c1D01d3D7C
# 1  0xe126b3E5d052f1F575828f61fEBA4f4f2603652a
# 2  0x531Eb60b2dDE9a841BA358EE033533AAF90D1feA
# 3  0x3A5bd1E37b099aE3386D13947b6a90d97675e5e3
# 4  0x18aa467E40E1deFB1956708830A343c1D01d3D7C
#
#                                         token             amount  amountUSD  \
# 0  0x0000000000000000000000000000000000000000  10000000000000000  18.368665
# 1  0x0000000000000000000000000000000000000000  10000000000000000  18.368665
# 2  0x0000000000000000000000000000000000000000   2000000000000000   3.673733
# 3  0x0000000000000000000000000000000000000000   2000000000000000   3.673733
# 4  0x0000000000000000000000000000000000000000   2000000000000000   3.673733
#
#        amountRoundToken                                         project_id  \
# 0  18380080590000000000  0x60c037f9dfa5daee0f07bc26fb73393ef924e36c73c4...
# 1  18380080590000000000  0xf05829c76e3da92a8942378240ab4dc70c8c509f558e...
# 2   3676016110000000000  0xb6a332decc38c703130a537ce7fcfe5a24bd85e52e07...
# 3   3676016110000000000  0xbe519f8c8f7ff2acb359dd757c5d2bf25b05d9fd29b8...
# 4   3676016110000000000  0x60c037f9dfa5daee0f07bc26fb73393ef924e36c73c4...
#
#                                          title    status  \
# 0                                     JediSwap  APPROVED
# 1  Revoke.cash - Helping you stay safe in web3  APPROVED
# 2     IDriss - A more usable web3 for everyone  APPROVED
# 3                                      Lenster  APPROVED
# 4                                     JediSwap  APPROVED
#
#                                      round_id  \
# 0  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 1  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 2  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 3  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 4  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
#
#                         round_name  round_type  matching_amount
# 0  Web3 Open Source Software Round         NaN                0
# 1  Web3 Open Source Software Round         NaN                0
# 2  Web3 Open Source Software Round         NaN                0
# 3  Web3 Open Source Software Round         NaN                0
# 4  Web3 Open Source Software Round         NaN                0

# %%
## TEMPORARY STUFF
# add time information here 

self_votes = df_all[df_all['voter'] == df_all['grantAddress']]
self_votes = self_votes.groupby(['voter', 'title', 'grantAddress', 'round_name', 'round_id' ]).agg({'amountUSD': 'sum', 'id': 'nunique'}).reset_index().sort_values('id', ascending=False)

# save self_votes to a csv
self_votes.to_csv('self_votes.csv', index=False)

display(self_votes).head(10)
# Out:
#                                          voter  \
# 45  0xD0352D08AA93C9bc9C79d2B3a53846DCd7c9cb92
# 18  0x5683921269B041fbE66882dd6CADd48B7e5b5817
# 31  0x9390fA8656A161442928b442300358D82bEC28b0
# 33  0x9FFA790731d0406B553F6fbd418A4580ec3E0269
# 19  0x5C07cbbD3F74925A362acAB166e9b1C59a5235c3
# 20  0x65ad2BF7E09af2597C140dF6386a3003d0F5f8Ee
# 21  0x65ad2BF7E09af2597C140dF6386a3003d0F5f8Ee
# 22  0x6B5918D8EF9094679F4b4e1Bf397a66eA411B118
# 23  0x6B5918D8EF9094679F4b4e1Bf397a66eA411B118
# 24  0x70B20209c83ec8D01e3c7F2ec77BDe7c40cDF2F6
# 25  0x72E1638bD8cD371Bfb04cF665b749A0E4ae38324
# 26  0x7f722b8b013Ac7Bd654B3B102Acc7573A32DB9bc
# 27  0x7f722b8b013Ac7Bd654B3B102Acc7573A32DB9bc
# 28  0x89F8d69BD4E7580B505c87fF5690a4B9324f3033
# 59  0xfC9265A28f66CF4561D74A4E25D7Bbd3F482B8e6
#
#                                                 title  \
# 45           ReFi Local Node: Cape Town, South Africa
# 18                                            OmniBTC
# 31                                    DeFinomics Labs
# 33                           ETH Tricolor ETH Ecuador
# 34                                           JobStash
# 35                                           KI-LIFE²
# 36                                              ENSAA
# 37                                              ENSAA
# 38                                       Just-DNA-Seq
# 39                                             Nextme
# 40                                             Nextme
# 41                                         HonestWork
# 42              Ethereum Staking Guides by CoinCashew
# 43  Endangered Tokens: Endangered Trees as ReFi Bi...
# 44                                       Emerging.Eco
# 0                                   Greenpill Podcast
# 46                                      登链社区(Upchain)
# 47                                      登链社区(Upchain)
# 48                        Pepemon: Degen Battleground
# 49                                       fatcat.money
# 50                                      Smart Invoice
# 51                                      Heavens Tools
# 52                               Blacks on Blockchain
# 53                                          Block2030
# 54                                      DeSci Youths
# 55  Decentralizing Journalism to Restore Public Trust
# 56  Decentralizing Journalism to Restore Public Trust
# 57  Decentralizing Journalism to Restore Public Trust
# 58                                      Asilo Digital
# 32                                    DeFinomics Labs
# 30                                      SetAvatar.eth
# 1                                            Lenstube
# 14  Learning Data Science on the Ethereum Blockcha...
# 2           Decentralized Effective Altruism (EA DAO)
# 3   Web3 Educational Programming for Underserved C...
# 4                 Decentalized Science NYC (DeSciNYC)
# 5                                          LabPredict
# 6                                          Climecheck
# 7                                AA Chinese Community
# 8                                        StatelessArt
# 9                               Decentralized Library
# 10                                            aikipay
# 11                                               DAZE
# 12                                            Rebioca
# 13                                         ReFi Tulum
# 15                                      Index Wallets
# 29                                     Women In DeFi
# 16  ReFi San José — a ReFi Lab from Costa Rica to ...
# 17  ReFi San José — a ReFi Lab from Costa Rica to ...
# 19                                        Pablito.eth
# 20                          Cosmos for Humanity | C4H
# 21                          Cosmos for Humanity | C4H
# 22                            Infinite Garden Library
# 23                            Infinite Garden Library
# 24                        W3Space(previously W3.work)
# 25  Stephen Reid: Metacrisis network weaver and in...
# 26                KOKO DAO saving forests in Colombia
# 27                KOKO DAO saving forests in Colombia
# 28  diosdao.xyz by Mycelia : Indigenous Public Goo...
# 59  Treegens - The Most Transparent & Rewarding Tr...
#
#                                   grantAddress  \
# 45  0xD0352D08AA93C9bc9C79d2B3a53846DCd7c9cb92
# 29  0x8ae4A38768Cb5c5b5F9f9AeCA1b8009b587BDa1A
# 16  0x526C9C964440EBc308Ac95f3Df68feB5673A4714
# 17  0x526C9C964440EBc308Ac95f3Df68feB5673A4714
# 19  0x5C07cbbD3F74925A362acAB166e9b1C59a5235c3
# 20  0x65ad2BF7E09af2597C140dF6386a3003d0F5f8Ee
# 21  0x65ad2BF7E09af2597C140dF6386a3003d0F5f8Ee
# 22  0x6B5918D8EF9094679F4b4e1Bf397a66eA411B118
# 23  0x6B5918D8EF9094679F4b4e1Bf397a66eA411B118
# 24  0x70B20209c83ec8D01e3c7F2ec77BDe7c40cDF2F6
# 25  0x72E1638bD8cD371Bfb04cF665b749A0E4ae38324
# 26  0x7f722b8b013Ac7Bd654B3B102Acc7573A32DB9bc
# 27  0x7f722b8b013Ac7Bd654B3B102Acc7573A32DB9bc
# 28  0x89F8d69BD4E7580B505c87fF5690a4B9324f3033
# 59  0xfC9265A28f66CF4561D74A4E25D7Bbd3F482B8e6
#
#                              round_name  \
# 45                     ReFi Local Nodes
# 18      Web3 Open Source Software Round
# 31                    Token Engineering
# 33         Web3 Community and Education
# 34         Web3 Community and Education
# 35                           Metacrisis
# 36                        ENS Ecosystem
# 37  Global Chinese Community beta round
# 38        DeSci (Decentralized Science)
# 39                        ENS Ecosystem
# 40                          Web3 Social
# 41      Web3 Open Source Software Round
# 42              Ethereum Infrastructure
# 43                    Climate Solutions
# 44                    Climate Solutions
# 0                            Metacrisis
# 46  Global Chinese Community beta round
# 47         Web3 Community and Education
# 48      Web3 Open Source Software Round
# 49      Web3 Open Source Software Round
# 50      Web3 Open Source Software Round
# 51                        ENS Ecosystem
# 52         Web3 Community and Education
# 53                    Climate Solutions
# 54        DeSci (Decentralized Science)
# 55                      Mantle Grants 1
# 56                           Metacrisis
# 57         Web3 Community and Education
# 58         Web3 Community and Education
# 32         Web3 Community and Education
# 30                        ENS Ecosystem
# 1       Web3 Open Source Software Round
# 14        DeSci (Decentralized Science)
# 2                            Metacrisis
# 3          Web3 Community and Education
# 4         DeSci (Decentralized Science)
# 5         DeSci (Decentralized Science)
# 6                     Climate Solutions
# 7          Web3 Community and Education
# 8       Web3 Open Source Software Round
# 9          Web3 Community and Education
# 10      Web3 Open Source Software Round
# 11         Web3 Community and Education
# 12                    Climate Solutions
# 13                     ReFi Local Nodes
# 15                    Token Engineering
# 29         Web3 Community and Education
# 16                           Metacrisis
# 17                     ReFi Local Nodes
# 19         Web3 Community and Education
# 20                    Climate Solutions
# 21        DeSci (Decentralized Science)
# 22                           Metacrisis
# 23         Web3 Community and Education
# 24      Web3 Open Source Software Round
# 25                           Metacrisis
# 26                    Climate Solutions
# 27                           Metacrisis
# 28                           Metacrisis
# 59                    Climate Solutions
#
#                                       round_id    amountUSD  id
# 45  0x64aa545C9C63944f8e765d9a65eda3cbbDc6e620    16.470288   3
# 18  0x12BB5bBbFE596dbc489d209299B8302c3300fa40    39.043027   2
# 31  0x9E669c0A6e075F14ba9d9D98C3580aD67E20ec38     4.115243   1
# 82008  0xD165df4296C85e780509fa1eace0150d945d49Fd
# 82018  0xD165df4296C85e780509fa1eace0150d945d49Fd
# 82031  0xD165df4296C85e780509fa1eace0150d945d49Fd
# 82050  0xD165df4296C85e780509fa1eace0150d945d49Fd
# 82059  0xD165df4296C85e780509fa1eace0150d945d49Fd
# 82074  0xD165df4296C85e780509fa1eace0150d945d49Fd
#
#                                             token                amount  \
# 81907  0x0000000000000000000000000000000000000000      3000000000000000
# 81931  0x0000000000000000000000000000000000000000      2000000000000000
# 81977  0x6B175474E89094C44Da98b954EedeAC495271d0F   5010000000000000000
# 82001  0x0000000000000000000000000000000000000000      5000000000000000
# 82008  0x0000000000000000000000000000000000000000       800000000000000
# 82018  0x6B175474E89094C44Da98b954EedeAC495271d0F   1000000000000000000
# 82031  0x0000000000000000000000000000000000000000     10000000000000000
# 82050  0x0000000000000000000000000000000000000000      1000000000000000
# 82059  0x0000000000000000000000000000000000000000       600000000000000
# 82074  0x6B175474E89094C44Da98b954EedeAC495271d0F  11000000000000000000
#
#        amountUSD      amountRoundToken  \
# 81907       5.61   5602369880000000000
# 81931       3.74   3734913250000000000
# 81977       5.01   5010000000000000000
# 82001       9.33   9333447300000000000
# 82008       1.50   1501746640000000000
# 82018       1.00   1000000000000000000
# 82031      18.95  18931471500000000000
# 82050       1.91   1915016110000000000
# 82059       1.15   1149190920000000000
# 82074      11.01  11000000000000000000
#
#                                               project_id      title    status  \
# 81907  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 81931  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 81977  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82001  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82008  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82018  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82031  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82050  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82059  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
# 82074  0x76eabce511626d1d54bdae4770c3dc172bffca39ba53...  EthStaker  APPROVED
#
#                                          round_id               round_name  \
# 81907  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 81931  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 81977  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82001  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82008  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82018  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82031  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82050  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82059  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
# 82074  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094  Ethereum Infrastructure
#
#        round_type  matching_amount
# 81907         NaN                0
# 81931         NaN                0
# 81977         NaN                0
# 82001         NaN                0
# 82008         NaN                0
# 82018         NaN                0
# 82031         NaN                0
# 82050         NaN                0
# 82059         NaN                0
# 82074         NaN                0

# %%
# read self_votes.csv
df = pd.read_csv('self_votes.csv')
print(df['amountUSD'].sum())
# Out:
# 5231.73080399

# %%
self_votes = self_votes.sort_values('amountUSD', ascending=False).head(15)
self_votes['title'] = self_votes['title'].str[:15]
fig = px.bar(self_votes, x='title', y='amountUSD', color='title', title='Self Votes')
fig.update_traces(texttemplate='%{y:$.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=7, uniformtext_mode='hide')
fig.show()

# %%
# TEMP CLIMATE PULL

df_alpha_climate = load_round_votes_data('0x1b165fE4DA6bC58AB8370DDC763d367D29F50Ef0')
df_alpha_climate_voters = df_alpha_climate['voter'].unique()
df_alpha_climate_voters = pd.DataFrame(df_alpha_climate_voters, columns=['address'])
display(df_alpha_climate_voters)
# filter to round_id = 0x421510312C40486965767be5Ea603Aa8a5707983
df_climate = df_all[df_all['round_id'] == '0x421510312C40486965767be5Ea603Aa8a5707983']
df_climate_voters = df_climate['voter'].unique()
df_climate_voters = pd.DataFrame(df_climate_voters, columns=['address'])
# save to csv
# append df_climate_voters to df_alpha_climate_voters
df_climate_voters = pd.concat([df_alpha_climate_voters, df_climate_voters])
# drop duplicates
df_climate_voters = df_climate_voters.drop_duplicates()
df_climate_voters.to_csv('alpha_beta_climate_voters.csv', index=False)

# %%
def load_chain_data(chain_id):
    chain_url = 'https://indexer-grants-stack.gitcoin.co/data/' + chain_id + '/rounds.json'
    try:
        response = requests.get(chain_url)
        if response.status_code == 200:
            chain_data = response.json()
            rounds = []
            for round in chain_data:
                if round['metadata'] is not None:
                    round_data = {
                        'round_id': round['id'],
                        'name': round['metadata']['name'],
                        'amountUSD': round['amountUSD'],
                        'votes': round['votes'],
                        'description': round['metadata']['description'] if 'description' in round['metadata'] else '',
                        'matchingFundsAvailable': round['metadata']['matchingFunds']['matchingFundsAvailable'] if 'matchingFunds' in round['metadata'] else '',
                        'matchingCap': round['metadata']['matchingFunds']['matchingCap'] if 'matchingFunds' in round['metadata'] else '',
                        'roundStartTime': datetime.datetime.utcfromtimestamp(int(round['roundStartTime'])), # create a datetime object from the timestamp in UTC time
                        'roundEndTime': datetime.datetime.utcfromtimestamp(int(round['roundEndTime']))
                    }
                    rounds.append(round_data)
            df = pd.DataFrame(rounds)
            # Filter to beta rounds
            start_time = datetime.datetime(2023, 4, 26, 15, 0, 0)
            end_time = datetime.datetime(2023, 5, 9, 23, 59, 0)
            # filter to only include rounds with votes > 0 and roundStartTime <= start_time and roundEndTime == end_time
            df = df[(df['votes'] > 0) & (df['roundStartTime'] <= start_time) & (df['roundEndTime'] == end_time)]
            return df 
    except: 
        return pd.DataFrame()

# %%
# display all
pd.set_option('display.max_rows', None)
print('boobs')
display(load_chain_data('1'))
# Out:
# boobs
#                                       round_id  \
# 12  0x12BB5bBbFE596dbc489d209299B8302c3300fa40
# 13  0xdf22a2C8F6BA9376fF17EE13E6154B784ee92094
# 15  0x274554EB289004e15A7679123901B7F070dDa0fa
# 16  0xAA40E2E5c8df03d792A52B5458959C320F86ca18
# 17  0x421510312C40486965767be5Ea603Aa8a5707983
# 18  0x8aA06b3b8cAc2970857F4E0fD78F21dc01AAdE94
# 19  0x905eFBaBe2d52cD648FAdfafCeC8D6C8c60F7423
# 20  0x9E669c0A6e075F14ba9d9D98C3580aD67E20ec38
# 21  0x9C3B81967EafBA0a451E324417DD4F3F353b997b
# 22  0xF1C021DF6Dc6b2dC2E5A837CDFDDC2f42503233B
# 23  0x6e8dC2e623204D61b0E59E668702654aE336c9f7
# 25  0x64E5b2228eF31437909900B38fC42Dd5E4B83147
# 26  0x859FaeAa266BA13bd1E72eB6dd7A223902d1adFE
# 27  0x32c49d2dA5f6866a057e4aA2058c62A2974a5623
# 28  0x64aa545C9C63944f8e765d9a65eda3cbbDc6e620
#
#                                    name  amountUSD  votes description  \
# 12      Web3 Open Source Software Round  329305.79  81508
# 13              Ethereum Infrastructure   41806.14   4287
# 15                        ZK Tech Round   30570.96   8498
# 16         Web3 Community and Education   62002.91   2835
# 17                    Climate Solutions   39944.54   1894
# 18                           Metacrisis   17534.03    591
# 19                   The Phantom Menace    1405.05    183
# 20                    Token Engineering    6112.97    254
# 21                          Web3 Social   25294.66   2519
# 22                      Mantle Grants 1    9296.43   1326
# 23        DeSci (Decentralized Science)   18017.13    920
# 25                        ENS Ecosystem    8436.35    680
# 26  Global Chinese Community beta round    1933.11    188
# 27                      Crypto Advocacy    7573.33    578
# 28                     ReFi Local Nodes     539.84     80
#
#    matchingFundsAvailable matchingCap      roundStartTime        roundEndTime
# 12                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 13                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 15                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 16                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 17                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 18                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 19                                    2023-04-25 00:00:00 2023-05-09 23:59:00
# 20                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 21                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 22                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 23                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 25                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 26                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 27                                    2023-04-25 12:00:00 2023-05-09 23:59:00
# 28                                    2023-04-26 15:00:00 2023-05-09 23:59:00
